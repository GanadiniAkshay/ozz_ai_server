# %%
#Import future to add compatiability between python2 and python3
from __future__ import absolute_import, division, print_function

# %%
#import os to deal with os tasks like opening files etc
import os
#import logging to enable logging
import logging
#import math libraries
import math
#import json library
import json
#import operator library for sorting dicts
import operator

# %%
import spacy
nlp = spacy.load('en')

# %%
#import porter stemmer from nltk
from nltk.stem.porter import PorterStemmer
porter_stemmer = PorterStemmer()

# %%
#import required functions from textblob library
from textblob import TextBlob as tb

# %%
#def fuctions that will be useful for creating the tf-idf calculations

#function to compute term frequency
def tf(word, blob):
    return blob.words.count(word) / len(blob.words)

#function to compute number of documents containg the word
def n_containing(word, bloblist):
    return sum(1 for blob in bloblist if word in blob.words)

#function to compute inverse document frequency
def idf(word, bloblist):
    return math.log(len(bloblist) / (1 + n_containing(word, bloblist)))

#function to compute tf-idf by multiplying term frequency with inverse document frequency
def tfidf(word, blob, bloblist):
    return tf(word, blob) * idf(word, bloblist)

# %%
blobs    = {}
bloblist = []

with open('data.json','r') as f:
    data = json.load(f)

for doc in data:
    data_val = tb((doc + " " + "".join(data[doc])).lower())
    
    blobs[doc] = data_val
    bloblist.append(data_val)

# %%
results = {}


for blob in blobs:
    scores = {word: tfidf(word, blobs[blob], bloblist) for word in blobs[blob].words}
    sorted_words = sorted(scores.items(), key=lambda x: x[1], reverse=True)
        
    #store the result
    results[blob] = sorted_words

print(results)
# Out:
# {'Anti-lock Braking System (ABS)': [('braking', 0.1627222757294336), ('driver', 0.11828784805675244), ('emergency', 0.11286014093856547), ('work', 0.09367080623963028), ('systems', 0.07915463491900315), ('brakes', 0.07915463491900315), ('pumping', 0.056430070469282737), ('prevention', 0.056430070469282737), ('lockup', 0.056430070469282737), ('retain', 0.056430070469282737), ('capabilities', 0.056430070469282737), ('fool', 0.056430070469282737), ('purchasing', 0.056430070469282737), ('advised', 0.056430070469282737), ('insist', 0.056430070469282737), ('demonstrating', 0.056430070469282737), ('applies', 0.056430070469282737), ('pumps', 0.056430070469282737), ('he', 0.056430070469282737), ('previously', 0.056430070469282737), ('sense', 0.05218436253097735), ('allow', 0.05218436253097735), ('heavy', 0.05218436253097735), ('constant', 0.05218436253097735), ('wheel', 0.051754994716905166), ('dealership', 0.04917198480896917), ('proper', 0.04917198480896917), ('properly', 0.04917198480896917), ('would', 0.04683540311981514), ('well', 0.04683540311981514), ('automatically', 0.044926276870663785), ('rotation', 0.0433121336263993), ('pump', 0.0433121336263993), ('conditions', 0.0433121336263993), ('maintenance', 0.0433121336263993), ('do', 0.0406805689323584), ('been', 0.0406805689323584), ('if', 0.03766819121035022), ('such', 0.036830047674501674), ('and', 0.03632599592743291), ('these', 0.03605404796608574), ('any', 0.03533160952119619), ('pressure', 0.03533160952119619), ('not', 0.03533160952119619), ('system', 0.03505871165444587), ('use', 0.03465581348834204), ('may', 0.03180834002778035), ('have', 0.03085575596279892), ('during', 0.03041010555003666), ('most', 0.029982650110033985), ('steering', 0.02957196201418811), ('taught.braking', 0.028215035234641368), ('taught', 0.028215035234641368), ('be', 0.026459380616618143), ('when', 0.02616439761173127), ('anti-lock', 0.026092181265488675), ('abs', 0.026092181265488675), ('the', 0.020685249703935902), ('as', 0.019201294956304578), ('it', 0.01905276474696472), ('of', 0.018378555552353223), ('for', 0.017934775475491358), ('with', 0.01754449909018003), ('vehicle', 0.01704577606411454), ('on', 0.01704577606411454), ('to', 0.01600207155041319), ('which', 0.015055790693560979), ('in', 0.010034083046839658), ('a', 0.007925370381575814)], 'Air-conditioning/AC': [('globally', 0.20727198960832696), ('chilled', 0.20727198960832696), ('quick', 0.19167717775801293), ('1970', 0.18061248266371369), ('1990', 0.18061248266371369), ('cabin', 0.17203003838239792), ('since', 0.16501767081339966), ('causes', 0.16501767081339966), ('way', 0.16501767081339966), ('usa', 0.15908879851235128), ('cooling', 0.15908879851235128), ('many', 0.14170475529146445), ('standard', 0.1272934687744871), ('during', 0.1116986569241731), ('air', 0.1057697846231247), ('air-conditioning/ac', 0.10363599480416348), ('flow.introduced', 0.10363599480416348), ('cars', 0.09610384507385908), ('introduced', 0.08250883540669983), ('flow', 0.07954439925617564), ("'s", 0.07776061153192411), ('as', 0.07052783339719566), ('on', 0.0626104466970361), ('by', 0.055301077355195134), ('of', 0.045003898852557254), ('in', 0.03685595888358413), ('the', 0.006907137575964611)], 'Air Brakes': [('heavy-duty', 0.47462920206746056), ('trucks', 0.44723090945300525), ('using', 0.42597914266117576), ('compressed', 0.4086151848712753), ('air', 0.39285920002874886), ('found', 0.3426011676750901), ('operate.usually', 0.25662246332459526), ('operate', 0.20430759243563765), ('brakes', 0.17998256273249524), ('on', 0.15503539182123222), ('usually', 0.12312911185285552), ('to', 0.07277132538402187)], 'Air Injection': [('exhaust', 0.2525360939155218), ('injection', 0.17403379863898305), ('fresh', 0.1562049776758406), ('burning', 0.1562049776758406), ('leftover', 0.1562049776758406), ('ports', 0.14445236584661844), ('present', 0.14445236584661844), ('combined', 0.13611375505091466), ('reducing', 0.12964582602731436), ('method', 0.12436114322169249), ('causes', 0.1243 ...

# %%
#Store the results in a JSON file
with open("tfidf_new.json","w") as outFile:
    json.dump(results,outFile)

# %%
#build inverted index
inv_index = {}

for key in results:
    for value in results[key]:
        word, score = value
        
        if word in inv_index:
            inv_index[word].append((key,score))
        else:
            inv_index[word] = [(key,score)]
print(inv_index)
# Out:
# {'braking': [('Anti-lock Braking System (ABS)', 0.1627222757294336), ('Brake Pad', 0.045705815682826195), ('Drum Brakes', 0.18951191868488912), ('Hydraulic', 0.17659065150182848), ('Master Cylinder', 0.11260853139247035), ('Road test', 0.1363155906329904), ('Traction Control', 0.08354826522667155), ('Zero-offset steering', 0.13169472315390598)], 'driver': [('Anti-lock Braking System (ABS)', 0.11828784805675244), ('Brake Booster', 0.13135452894674252), ('Bucket Seats', 0.11527030091244751), ('Chassis', 0.07844784367652678), ('Coupe de Ville', 0.18827482482366428), ('Cruise Control', 0.17115893165787663), ('Dashboard', 0.04092930974427485), ('Feed-through', 0.21724018248884341), ('Four-Wheel Steering', 0.06206862356824098), ('Fuel Cell', 0.12551654988244285), ('Lap-and-Shoulder Belt', 0.05483732761854299), ('Master Cylinder', 0.0818586194885497), ('Oversteer', 0.08557946582893831), ('Rally', 0.07431900979881484), ('Rev counter', 0.11074989695509664), ('Rollcage', 0.25673839748681493), ('Shift Interlock', 0.11527030091244751), ('Skidpad', 0.061393964616412264), ('Speedo', 0.14863801959762968), ('Switch-gear', 0.21724018248884341), ('Tachometer', 0.08557946582893831), ('Transmission', 0.03922392183826339), ('Turbo Lag', 0.09573296177474455), ('Understeer', 0.08825382413609263), ('Winston Cup', 0.0733538278533757)], 'emergency': [('Anti-lock Braking System (ABS)', 0.11286014093856547)], 'work': [('Anti-lock Braking System (ABS)', 0.09367080623963028), ('Cruiser skirts', 0.07332427865479256), ('Fuel System', 0.04517960603982168), ('Pitstop', 0.1397744061856983)], 'systems': [('Anti-lock Braking System (ABS)', 0.07915463491900315), ('ATC', 0.23622711358640003), ('Ball Joint', 0.13998643768082963), ('Carburetor', 0.09691368762518975), ('Engine management system', 0.09946404782585264), ('Fuel System', 0.22906871620499397), ('Power Steering Fluid', 0.13033220059939313), ('R-134a', 0.12392242024204592), ('Traction Control', 0.08128244768564302)], 'brakes': [('Anti-lock Braking System (ABS)', 0.07915463491900315), ('Air Brakes', 0.17998256273249524), ('Brake Pull', 0.14262769122197738), ('Brake Rotor', 0.11453435810249699), ('Brake Shoe', 0.1679837252169956), ('Carbon Brakes', 0.17337769804506425), ('Disc Brakes', 0.04446628020449883), ('Drum Brakes', 0.09218619066786343), ('Vented Disc Brakes', 0.15748474239093335)], 'pumping': [('Anti-lock Braking System (ABS)', 0.056430070469282737)], 'prevention': [('Anti-lock Braking System (ABS)', 0.056430070469282737)], 'lockup': [('Anti-lock Braking System (ABS)', 0.056430070469282737)], 'retain': [('Anti-lock Braking System (ABS)', 0.056430070469282737)], 'capabilities': [('Anti-lock Braking System (ABS)', 0.056430070469282737)], 'fool': [('Anti-lock Braking System (ABS)', 0.056430070469282737)], 'purchasing': [('Anti-lock Braking System (ABS)', 0.056430070469282737)], 'advised': [('Anti-lock Braking System (ABS)', 0.056430070469282737)], 'insist': [('Anti-lock Braking System (ABS)', 0.056430070469282737)], 'demonstrating': [('Anti-lock Braking System (ABS)', 0.056430070469282737)], 'applies': [('Anti-lock Braking System (ABS)', 0.056430070469282737)], 'pumps': [('Anti-lock Braking System (ABS)', 0.056430070469282737)], 'he': [('Anti-lock Braking System (ABS)', 0.056430070469282737)], 'previously': [('Anti-lock Braking System (ABS)', 0.056430070469282737)], 'sense': [('Anti-lock Braking System (ABS)', 0.05218436253097735), ('Electronic Mufflers', 0.08979471390465471)], 'allow': [('Anti-lock Braking System (ABS)', 0.05218436253097735), ('Transmission', 0.069216758634838)], 'heavy': [('Anti-lock Braking System (ABS)', 0.05218436253097735), ('Power-to-Weight Ratio', 0.05568275554981381)], 'constant': [('Anti-lock Braking System (ABS)', 0.05218436253097735), ('Constant-Velocity Joint (CV Joint)', 0.11199116003838958)], 'wheel': [('Anti-lock Braking System (ABS)', 0.051754994716905166), ('Alloy Wheels', 0.1594387740472401), ('Brake Pad', 0.058148258770169915), ('Brake Shoe', 0.10983559989920985), ('Co ...

# %%
#Store the inverted index in a JSON file
with open("invindex_new.json","w") as outFile:
    json.dump(inv_index,outFile)

# %%
#Calculate score for a query

query = "how to use brakes"

#remove ? symbol
query = query.replace("?","")

#turn to lowercase
query = query.lower()

#result set as a dictionary of key-value
res_set = {}

#get list of words to query over
words = query.split(" ")
words = list(set(words))

#get top 10 documents for each word
for word in words:
    if not word in inv_index:
        continue
    else:
        responses = inv_index[word][:10]

        for response in responses:
            file,score = response

            if file in res_set:
                res_set[file] += score
            else:
                res_set[file] = score

            
sorted_results = sorted(res_set.items(), key=operator.itemgetter(1), reverse=True)
print(sorted_results[:5])

score1 = sorted_results[0][1]
score2 = sorted_results[1][1]
score3 = sorted_results[2][1]
score4 = sorted_results[3][1]
score5 = sorted_results[4][1]

print(score2-score1, score3-score2, score4-score3, score5-score4)
# Out:
# [('Air Brakes', 0.2527538881165171), ('Camber', 0.2236390498971173), ('Automatic Transmission', 0.22020157322534567), ('Rev counter', 0.17540317638989592), ('Carbon Brakes', 0.17337769804506425)]
# -0.029114838219399808 -0.003437476671771633 -0.044798396835449755 -0.0020254783448316604
